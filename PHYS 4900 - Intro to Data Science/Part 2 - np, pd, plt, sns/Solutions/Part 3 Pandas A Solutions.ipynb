# %% [markdown]
# # $\LARGE Pandas$
#
# # Act 1 - Read Data
# #### Import numpy and pandas below

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1.1 Read your data "HiGAL_clump_catalogue_v1.tab" and call it "cat", use read_csv

# %%
cat = pd.read_csv('Data/HiGAL_clump_catalogue_v1.tab', sep='\t')

# %% [markdown]
# #### 1.2 print out the head of cat

# %%
cat.head()
# Out:
#    Unnamed: 0     ID           DESIGNATION      GLON       GLAT          ra  \
# 0         NaN  FLOAT                  CHAR    DOUBLE     DOUBLE      DOUBLE
# 1         NaN    deg                   deg       deg        deg          Jy
# 2         NaN   4454  HIGALBM9.2545+1.0842  9.254488   1.084173  270.542950
# 3         NaN   4455  HIGALBM9.2569-0.2825  9.256889  -0.282502  271.817960
# 4         NaN   4456  HIGALBM9.2582-0.4725  9.258172  -0.472514  271.996620
#
#           dec DESIGNATION_70    F70   DF70  ...    MASS  DMASS   TEMP  DTEMP  \
# 0      DOUBLE           CHAR  FLOAT  FLOAT  ...   FLOAT  FLOAT  FLOAT  FLOAT
# 1          Jy             Jy     Jy     Jy  ...     NaN    NaN    NaN    NaN
# 2  -20.408795              -  0.000  0.000  ...   -7.63  -1.86  10.84   0.48
# 3  -21.076705              -  0.000  0.000  ...  -30.79  -6.40  10.31   0.42
# 4  -21.167985              -  0.000  0.000  ...  -10.36  -2.69  12.32   0.66
#
# ...

# %% [markdown]
# #### 1.3 drop your first and last column

# %%
cat.drop(['Unnamed: 0', 'Unnamed: 75'], axis=1, inplace=True)

# %% [markdown]
# #### 1.3 drop your the first two rows!

# %%
cat.drop([0,1], inplace=True)

# %% [markdown]
# Double check if you dropped them. Did you use inplace=True?

# %%
cat
# Out:
#          ID            DESIGNATION       GLON       GLAT          ra  \
# 2      4454   HIGALBM9.2545+1.0842   9.254488   1.084173  270.542950
# 3      4455   HIGALBM9.2569-0.2825   9.256889  -0.282502  271.817960
# 4      4456   HIGALBM9.2582-0.4725   9.258172  -0.472514  271.996620
# 5      4457   HIGALBM9.2604-0.2253   9.260426  -0.225272  271.766240
# 6      4458   HIGALBM9.2626-0.1134   9.262623  -0.113445  271.662780
# ...     ...                    ...        ...        ...         ...
# 1729  16622  HIGALBM31.4906+0.8712  31.490578   0.871197  281.426880
# 1730  16623  HIGALBM31.4908+0.4419  31.490754   0.441868  281.809050
# 1731  16624  HIGALBM31.4946-0.0244  31.494575  -0.024419  282.225830
# 1732  16625  HIGALBM31.4962+0.1774  31.496159   0.177432  282.046880
# 1733  16626  HIGALBM31.4970-0.3651  31.496995  -0.365096  282.530210
#
#              dec          DESIGNATION_70     F70   DF70 F70_TOT  ...  \
# ...

# %% [markdown]
# #### 1.4 Use .info and .describe on your catalogue

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1732 entries, 2 to 1733
# Data columns (total 74 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1732 non-null   object
#  1   DESIGNATION       1732 non-null   object
#  2   GLON              1732 non-null   object
#  3   GLAT              1732 non-null   object
#  4   ra                1732 non-null   object
#  5   dec               1732 non-null   object
#  6   DESIGNATION_70    1732 non-null   object
#  7   F70               1732 non-null   object
#  8   DF70              1732 non-null   object
#  9   F70_TOT           1732 non-null   object
#  10  DF70_TOT          1732 non-null   object
#  11  F70_ADD           1732 non-null   object
#  12  DF70_ADD          1732 non-null   object
#  13  F70_ADD_TOT       1732 non-null   object
#  14  DF70_ADD_TOT      1732 non-null   object
#  15  ULIM_70           1732 non-null   object
# ...

# %%
cat.describe()
# Out:
#           ID            DESIGNATION       GLON       GLAT          ra  \
# count   1732                   1732       1732       1732        1732
# unique  1732                   1732       1731       1730        1729
# top     4481  HIGALBM30.3068+0.0800  30.394553  -0.022185  282.164530
# freq       1                      1          2          2           2
#
#               dec DESIGNATION_70    F70   DF70 F70_TOT  ... EVOL_FLAG   MASS  \
# count        1732           1732   1732   1732    1732  ...      1732   1732
# unique       1732            707    696    555     726  ...         3   1476
# top     -2.030205              -  0.000  0.000   0.000  ...         1  -6.95
# freq            1           1026   1026   1038     995  ...       869      5
#
#         DMASS   TEMP DTEMP LAM_0_TK  L_BOL LRATIO  T_BOL SURF_DENS
# count    1732   1732  1732     1732   1732   1732   1732      1732
# unique   1286    513    73      397   1447   1369   1113       718
# ...

# %% [markdown]
# Spend a few minutes here. Does it even make sense? What type of information are you getting?
# Your data type seems to be object. Do we need to convert them?
# We need to:
# - Convert ID to an int
# - Convert any Designations, and FIT_TYPE to a string
# - Convert the rest to float
#
# #### 1.5: Print out name of columns

# %%
cat.columns
# Out:
# Index(['ID', 'DESIGNATION', 'GLON', 'GLAT', 'ra', 'dec', 'DESIGNATION_70',
#        'F70', 'DF70', 'F70_TOT', 'DF70_TOT', 'F70_ADD', 'DF70_ADD',
#        'F70_ADD_TOT', 'DF70_ADD_TOT', 'ULIM_70', 'DESIGNATION_160', 'F160',
#        'DF160', 'F160_ADD', 'DF160_ADD', 'ULIM_160', 'DESIGNATION_250', 'F250',
#        'DF250', 'DESIGNATION_350', 'F350', 'DF350', 'FSC350', 'DFSC350',
#        'DESIGNATION_500', 'F500', 'DF500', 'FSC500', 'DFSC500',
#        'DESIGNATION_21', 'F21', 'DF21', 'F21_TOT', 'DF21_TOT',
#        'DESIGNATION_22', 'F22', 'DF22', 'F22_TOT', 'DF22_TOT',
#        'DESIGNATION_24', 'F24', 'DF24', 'F24_TOT', 'DF24_TOT',
#        'DESIGNATION_870', 'F870', 'DF870', 'DESIGNATION_1100', 'F1100',
#        'DF1100', 'DFWHM250', 'DIST', 'NEAR_DIST', 'FAR_DIST', 'DIST_FLAG',
#        'DIAM', 'M_LARS', 'FIT_TYPE', 'EVOL_FLAG', 'MASS', 'DMASS', 'TEMP',
#        'DTEMP', 'LAM_0_TK', 'L_BOL', 'LRATIO', 'T_BOL', 'SURF_DENS'],
#       dtype='object')

# %% [markdown]
# #### Use apply and lambda to change the 'ID" to int

# %%
cat['ID']=cat['ID'].apply(lambda x:int(x))

# %% [markdown]
# #### Use .astype to change Designations, FIT_TYPE, DIST_FLAG to string

# %%
cat[['DESIGNATION', 'DESIGNATION_70',
     'DESIGNATION_160', 'DESIGNATION_250', 'DESIGNATION_350', 'DESIGNATION_500', 
     'DESIGNATION_21',
     'DESIGNATION_22', 
     'DESIGNATION_24',
     'DESIGNATION_870',
     'DESIGNATION_1100',
     'FIT_TYPE', 'DIST_FLAG']] = cat[['DESIGNATION', 'DESIGNATION_70',
     'DESIGNATION_160', 'DESIGNATION_250', 'DESIGNATION_350', 'DESIGNATION_500', 
     'DESIGNATION_21',
     'DESIGNATION_22', 
     'DESIGNATION_24',
     'DESIGNATION_870',
     'DESIGNATION_1100',
     'FIT_TYPE', 'DIST_FLAG']].astype('str')

# %% [markdown]
# Use .astype to convert the rest to float

# %%
cat[['GLON', 'GLAT', 'ra', 'dec',
       'F70', 'DF70', 'F70_TOT', 'DF70_TOT', 'F70_ADD', 'DF70_ADD',
       'F70_ADD_TOT', 'DF70_ADD_TOT', 'ULIM_70', 'F160',
       'DF160', 'F160_ADD', 'DF160_ADD', 'ULIM_160', 'F250',
       'DF250', 'F350', 'DF350', 'FSC350', 'DFSC350',
       'F500', 'DF500', 'FSC500', 'DFSC500',
       'F21', 'DF21', 'F21_TOT', 'DF21_TOT',
       'F22', 'DF22', 'F22_TOT', 'DF22_TOT',
       'F24', 'DF24', 'F24_TOT', 'DF24_TOT',
       'F870', 'DF870', 'F1100',
       'DF1100', 'DFWHM250', 'DIST', 'NEAR_DIST', 'FAR_DIST',
       'DIAM', 'M_LARS', 'EVOL_FLAG', 'MASS', 'DMASS', 'TEMP',
       'DTEMP', 'LAM_0_TK', 'L_BOL', 'LRATIO', 'T_BOL', 'SURF_DENS']]=cat[['GLON', 'GLAT', 'ra', 'dec',
       'F70', 'DF70', 'F70_TOT', 'DF70_TOT', 'F70_ADD', 'DF70_ADD',
       'F70_ADD_TOT', 'DF70_ADD_TOT', 'ULIM_70', 'F160',
       'DF160', 'F160_ADD', 'DF160_ADD', 'ULIM_160', 'F250',
       'DF250', 'F350', 'DF350', 'FSC350', 'DFSC350',
       'F500', 'DF500', 'FSC500', 'DFSC500',
       'F21', 'DF21', 'F21_TOT', 'DF21_TOT',
       'F22', 'DF22', 'F22_TOT', 'DF22_TOT',
       'F24', 'DF24', 'F24_TOT', 'DF24_TOT',
       'F870', 'DF870', 'F1100',
       'DF1100', 'DFWHM250', 'DIST', 'NEAR_DIST', 'FAR_DIST',
       'DIAM', 'M_LARS', 'EVOL_FLAG', 'MASS', 'DMASS', 'TEMP',
       'DTEMP', 'LAM_0_TK', 'L_BOL', 'LRATIO', 'T_BOL', 'SURF_DENS']].astype('float')

# %% [markdown]
# #### Now run cat.info() & cat.describe() again

# %%
cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1732 entries, 2 to 1733
# Data columns (total 74 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                1732 non-null   int64
#  1   DESIGNATION       1732 non-null   object
#  2   GLON              1732 non-null   float64
#  3   GLAT              1732 non-null   float64
#  4   ra                1732 non-null   float64
#  5   dec               1732 non-null   float64
#  6   DESIGNATION_70    1732 non-null   object
#  7   F70               1732 non-null   float64
#  8   DF70              1732 non-null   float64
#  9   F70_TOT           1732 non-null   float64
#  10  DF70_TOT          1732 non-null   float64
#  11  F70_ADD           1732 non-null   float64
#  12  DF70_ADD          1732 non-null   float64
#  13  F70_ADD_TOT       1732 non-null   float64
#  14  DF70_ADD_TOT      1732 non-null   float64
#  15  ULIM_70           1732 non-null   float64
# ...

# %%
cat.describe()
# Out:
#                  ID         GLON         GLAT           ra          dec  \
# count   1732.000000  1732.000000  1732.000000  1732.000000  1732.000000
# mean   10666.594111    20.681977    -0.103156   277.147742   -10.894404
# std     5659.007313    10.301232     0.501320     4.875525     9.148600
# min     4454.000000     9.254488    -1.277056   270.542950   -21.484523
# 25%     4886.750000    10.152985    -0.453265   272.292923   -20.205528
# 50%    15760.500000    30.025016    -0.108080   281.041685    -2.864130
# 75%    16193.250000    30.745236     0.225755   281.903080    -1.963998
# max    16626.000000    31.496995     1.242487   283.019690    -0.764793
#
#                F70         DF70     F70_TOT     DF70_TOT      F70_ADD  ...  \
# count  1732.000000  1732.000000  1732.00000  1732.000000  1732.000000  ...
# mean     21.261808     1.304742    25.18843     1.586124     0.026607  ...
# std     120.088239     7.180585   162.00792     8.120956     0.255311  ...
# ...

# %% [markdown]
# #### 1.6 Svae this new table as a csv file called "Data/HiGAL_clump_catalogue_correct_formatting.csv"

# %%
cat.to_csv('Data/HiGAL_clump_catalogue_correct_formatting.csv', index=False)

# %% [markdown]
# ![image.png](attachment:image.png)
