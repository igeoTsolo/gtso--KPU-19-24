# %% [markdown]
# # $\LARGE Data \ Visualization \ via \ Matplotlib.pyplot$
#
# # Act 1 - Read Data
# #### Import numpy, pandas, & matplotlib below

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.1 Read the corrected format data "Data/HiGAL_clump_catalogue_correct_formatting.csv" and call it "cat", use read_csv

# %%
cat = pd.read_csv('C:/Users/georg/Dropbox/Kwantlen/PHYS 4900 - Introduction to Data Science/Data/Star_Formation/HiGAL_clump_catalogue_correct_formatting.csv',)

# %% [markdown]
# # Act 2 - Create the following plots

# %% [markdown]
# #### 2.1 Use object oriented method. Define 15 points from (0,10). Plot $\sqrt x$

# %%
x = np.linspace(0,10,15)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,np.sqrt(x))

# %% [markdown]
# #### 2.2. Label your axes and add title

# %%
x = np.linspace(0,10,15)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('Root Squared Plot')
ax.set_xlabel('x axis')
ax.set_ylabel('$\sqrt{x}$')
ax.plot(x,np.sqrt(x))

# %% [markdown]
# #### 2.3. Add a smaller second plot of $x^2$ on the right side of this and have appropriate labels in.

# %%
x = np.linspace(0,10,15)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('Root Squared Plot')
ax.set_xlabel('x axis')
ax.set_ylabel('$\sqrt{x}$')
ax.plot(x,np.sqrt(x))

ax = fig.add_axes([.55,.1,.4,.4])
ax.set_title('Squared Plot')
ax.set_xlabel('x axis')
ax.set_ylabel('x$^2$')
ax.plot(x,x**2
       , c = 'r'
       , ls = '--')

# %% [markdown]
# #### 2.4. Can you update it to look like this?

# %%
x = np.linspace(0,10,15)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.set_title('Root Squared Plot')
ax.set_xlabel('x axis')
ax.set_ylabel('$\sqrt{x}$')
ax.plot(x,np.sqrt(x)
       , c = 'c'
       , ls = 'dotted'
       , lw = 4
       , marker = 'X'
       , markersize = 10
       , markerfacecolor = 'yellow'
       , markeredgewidth = 2
       , markeredgecolor = 'blue')

ax = fig.add_axes([.55,.1,.4,.4])
ax.set_title('Squared Plot')
ax.set_xlabel('x axis')
ax.set_ylabel('x$^2$')
ax.plot(x,x**2
       , c = 'r'
       , ls = '--')

# %% [markdown]
# # Act 3 - Subplots

# %% [markdown]
# #### Create the following plots

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4))
ax[0].plot(x,x**2
          , c = 'r'
          , lw = 10
          , alpha = .5)
ax[0].set_ylabel('x$^2$')

ax[1].plot(x,x**0.5)
ax[1].set_ylabel('$\sqrt{x}$')


for i in range(len(ax)):
    ax[i].set_xlabel('This title is the same as the one next to it')

# %% [markdown]
# #### 3.2. Add $20\cdot\sqrt{x}$ to the plot on the left, Make sure to add the legends in

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 2, figsize = (10,4))
ax[0].plot(x,x**2
          , c = 'r'
          , lw = 10
          , alpha = .5
          , label = 'x$^2$')
ax[0].plot(x,20*x**0.5
          , c = 'k'
          , lw = 10
          , alpha = 0.5
          , label = '$20 \cdot \sqrt{x}$')
ax[0].set_ylabel('x$^2$ and $20\sqrt{x}$')
ax[0].legend(loc = 2)


ax[1].plot(x,x**0.5)
ax[1].set_ylabel('$\sqrt{x}$')

for i in range(len(ax)):
    ax[i].set_xlabel('This title is the same as the one next to it')

# %% [markdown]
# # Act 4 - Smile!
# To be honest I don't know why we had Act 1 and imported the catalogue! So smile. Good practice though!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A few good resources:
#
# https://matplotlib.org/2.0.2/gallery.html
#
# https://github.com/rougier/matplotlib-tutorial
#
# https://github.com/matplotlib/matplotlib

# %% [markdown]
# ![image.png](attachment:image.png)
