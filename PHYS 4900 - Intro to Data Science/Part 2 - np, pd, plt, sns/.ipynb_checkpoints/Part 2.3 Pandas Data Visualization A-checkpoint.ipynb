# %% [markdown]
# # $\LARGE Data \ Visualization \ via \ Pandas$
#
# # Act 1 - Read Data
# #### Import numpy and pandas below

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### 1.1 Read the corrected format data "Data/HiGAL_clump_catalogue_correct_formatting.csv" and call it "cat", use read_csv

# %%
cat = pd.read_csv('C:/Users/georg/Dropbox/Kwantlen/PHYS 4900 - Introduction to Data Science/Data/Star_Formation/HiGAL_clump_catalogue_correct_formatting.csv',)

# %% [markdown]
# #### 1.2 print out the head of cat

# %%
cat.head()
# Out:
#      ID           DESIGNATION      GLON      GLAT         ra        dec  \
# 0  4454  HIGALBM9.2545+1.0842  9.254488  1.084173  270.54295 -20.408795
# 1  4455  HIGALBM9.2569-0.2825  9.256889 -0.282502  271.81796 -21.076705
# 2  4456  HIGALBM9.2582-0.4725  9.258172 -0.472514  271.99662 -21.167985
# 3  4457  HIGALBM9.2604-0.2253  9.260426 -0.225272  271.76624 -21.045749
# 4  4458  HIGALBM9.2626-0.1134  9.262623 -0.113445  271.66278 -20.989332
#
#   DESIGNATION_70  F70  DF70  F70_TOT  ...  EVOL_FLAG   MASS  DMASS   TEMP  \
# 0              -  0.0   0.0      0.0  ...        1.0  -7.63  -1.86  10.84
# 1              -  0.0   0.0      0.0  ...        1.0 -30.79  -6.40  10.31
# 2              -  0.0   0.0      0.0  ...        1.0 -10.36  -2.69  12.32
# 3              -  0.0   0.0      0.0  ...        1.0 -25.06  -7.33   9.47
# 4              -  0.0   0.0      0.0  ...        1.0 -50.04 -18.92   9.48
#
#    DTEMP  LAM_0_TK L_BOL  LRATIO  T_BOL  SURF_DENS
# ...

# %% [markdown]
# # Act 2 - Create the following plots

# %% [markdown]
# #### 2.1 create a histogram of the 'TEMP' (Temperature)

# %%
cat['TEMP'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Maybe 20 bins is more appropriate. Change it!

# %%
cat['TEMP'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Create a KDE plot of this

# %%
cat['TEMP'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# #### 2.2 create a histogram of the 'T_BOL' (Bolometric Temperature)

# %%
cat['T_BOL'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Maybe we don't need values bigger than 60 K. Plot for those values where smaller than 60 K

# %%
cat['T_BOL'][cat['T_BOL']<=60].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### 2.3 create a histogram of the 'SURF_DENS' (Surface Density)

# %%
cat['SURF_DENS'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Plot for those values where smaller than 2 and change number of bins to 20

# %%
cat['SURF_DENS'][cat['SURF_DENS']<2].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### 2.4 create a histogram of the 'L_BOL' (Luminosity)

# %%
cat['L_BOL'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We must have a few with the luminosity bigger than 10,000. Plot histogram where luminosity is smaller than 10,000

# %%
cat['L_BOL'][cat['L_BOL']<10000].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# We still have a few bigger 2000. Plot positive values where smaller than 2000!

# %%
cat['L_BOL'][(cat['L_BOL']<2000) & (cat['L_BOL']>0)].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### 2.5 create a histogram of the 'MASS' (Mass)

# %%
cat['MASS'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Plot those **positive** values smaller than 3000

# %%
cat['MASS'][(cat['MASS']<3000) & (cat['MASS']>0)].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Act 3 - Create a box plot
# #### Create the following

# %%
cat[['TEMP','T_BOL']].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Act 4 - Correlation between mass and luminosity

# %% [markdown]
# Create a scatter plot, weher x is mass, and y is luminosity

# %%
cat.plot.scatter(x='MASS', y='L_BOL')
# Out:
# <AxesSubplot:xlabel='MASS', ylabel='L_BOL'>

# %% [markdown]
# It does not seem to have any correlation. What if we change the colors with temperature?

# %%
cat.plot.scatter(x='MASS', y='L_BOL'
                , c = cat['TEMP'])
# Out:
# <AxesSubplot:xlabel='MASS', ylabel='L_BOL'>

# %% [markdown]
# Use cmap to distinguish it better

# %%
cat.plot.scatter(x='MASS', y='L_BOL'
                , c = cat['TEMP']
                , cmap = 'coolwarm')
# Out:
# <AxesSubplot:xlabel='MASS', ylabel='L_BOL'>

# %% [markdown]
# Well, your job as a physicist/sceintist begins now! You need to interprete it well. Explain what it means! Tell the story of your data in a way that people can understand it!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bonus: .plot.hexbin()
# - use shift + tab to explore this one
# - where Mass is positive and smaller than 2000
# - where Luminosity is positive and smaller than 3000
# - create the following plot.
# - Note: you would need to change the grid size
#
# It shows the density of the data points. See your plot above

# %%
cat[['MASS', 'L_BOL']][(cat['MASS']>0)&(cat['MASS']<2000) & (cat['L_BOL']>0)&(cat['L_BOL']<3000)].plot.hexbin(x='MASS', y='L_BOL'
        , gridsize = 10)
# Out:
# <AxesSubplot:xlabel='MASS', ylabel='L_BOL'>

# %% [markdown]
# ![image.png](attachment:image.png)
