# %% [markdown]
# # $\LARGE Decision \ Tree$
# # $\LARGE \& \ Random \ Forest$
#
# # Act 1 - Read Data
# #### Import the usual 4  packages!

# %% [markdown]
# Let's start by importing the important packages!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn import tree

# %% [markdown]
# Read your data

# %%
df=pd.read_csv('../Midterm/Data/6 class csv.csv')

# %% [markdown]
# check head, infor, describe

# %%
df.head()
# Out:
#    Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  Absolute magnitude(Mv)  \
# 0             3068          0.002400        0.1700                   16.12
# 1             3042          0.000500        0.1542                   16.60
# 2             2600          0.000300        0.1020                   18.70
# 3             2800          0.000200        0.1600                   16.65
# 4             1939          0.000138        0.1030                   20.06
#
#    Star type Star color Spectral Class
# 0          0        Red              M
# 1          0        Red              M
# 2          0        Red              M
# 3          0        Red              M
# 4          0        Red              M

# %%
df.describe()
# Out:
#        Temperature (K)  Luminosity(L/Lo)  Radius(R/Ro)  \
# count       240.000000        240.000000    240.000000
# mean      10497.462500     107188.361635    237.157781
# std        9552.425037     179432.244940    517.155763
# min        1939.000000          0.000080      0.008400
# 25%        3344.250000          0.000865      0.102750
# 50%        5776.000000          0.070500      0.762500
# 75%       15055.500000     198050.000000     42.750000
# max       40000.000000     849420.000000   1948.500000
#
#        Absolute magnitude(Mv)   Star type
# count              240.000000  240.000000
# mean                 4.382396    2.500000
# std                 10.532512    1.711394
# min                -11.920000    0.000000
# 25%                 -6.232500    1.000000
# 50%                  8.313000    2.500000
# 75%                 13.697500    4.000000
# max                 20.060000    5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Temperature (K)         240 non-null    int64
#  1   Luminosity(L/Lo)        240 non-null    float64
#  2   Radius(R/Ro)            240 non-null    float64
#  3   Absolute magnitude(Mv)  240 non-null    float64
#  4   Star type               240 non-null    int64
#  5   Star color              240 non-null    object
#  6   Spectral Class          240 non-null    object
# dtypes: float64(3), int64(2), object(2)
# memory usage: 13.2+ KB

# %% [markdown]
# #### Create the following plot

# %%
sb.scatterplot(x = df['Temperature (K)'], y = df['Temperature (K)']
               , hue = df['Spectral Class']
               , hue_order = ('O', 'B', 'A', 'F', 'G', 'K', 'M')
               , palette = 'Spectral_r')
# Out:
# <AxesSubplot:xlabel='Temperature (K)', ylabel='Temperature (K)'>

# %% [markdown]
# # Act 2 - Decision Tree and Random Forest to Predict Star Type
# **Note: This example is for educational purposes only**
#
#
# #### 2.1.1 Decisison Tree
# - X should contain ['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)','Absolute magnitude(Mv)']
# - y is ['Star Type']
# - perform train test split
# - create your decision tree model
# - fit the model to your training set
# - perform the predictions on your test set
# - evaluate your model (i.e. confusion matrix and classification_report)

# %%
df.columns
# Out:
# Index(['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)',
#        'Absolute magnitude(Mv)', 'Star type', 'Star color', 'Spectral Class'],
#       dtype='object')

# %%
x = df[['Temperature (K)', 'Luminosity(L/Lo)', 'Radius(R/Ro)', 'Absolute magnitude(Mv)']]
y = df['Star type']

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size = .33, random_state = 42)

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(xtrain, ytrain)
# Out:
# DecisionTreeClassifier()

# %%
pred = dtree.predict(xtest)

# %%
print(confusion_matrix(ytest, pred), '\n')
print(classification_report(ytest, pred))
# Out:
# [[16  0  0  0  0  0]
#  [ 0 13  0  0  0  0]
#  [ 0  0 12  0  0  0]
#  [ 0  0  0 11  0  0]
#  [ 0  0  0  0 12  0]
#  [ 0  0  0  0  0 16]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        12
#            5       1.00      1.00      1.00        16
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80

# %% [markdown]
# #### 2.1.2 Plot your decission tree
# - Look at the number of counts in each of the Star Type for y_train
# - plot your model (decision tree)

# %%
ytrain.value_counts()
# Out:
# 3    29
# 2    28
# 4    28
# 1    27
# 0    24
# 5    24
# Name: Star type, dtype: int64

# %%
plt.figure(figsize = (15, 15))
tree.plot_tree(dtree,
              feature_names = x.columns,
              class_names = True,
              filled = True)
# Out:
# [Text(0.4444444444444444, 0.9, 'Radius(R/Ro) <= 0.046\ngini = 0.832\nsamples = 160\nvalue = [24, 27, 28, 29, 28, 24]\nclass = y[3]'),
#  Text(0.3333333333333333, 0.7, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 28, 0, 0, 0]\nclass = y[2]'),
#  Text(0.5555555555555556, 0.7, 'Radius(R/Ro) <= 11.1\ngini = 0.799\nsamples = 132\nvalue = [24, 27, 0, 29, 28, 24]\nclass = y[3]'),
#  Text(0.3333333333333333, 0.5, 'Temperature (K) <= 3884.5\ngini = 0.665\nsamples = 80\nvalue = [24, 27, 0, 29, 0, 0]\nclass = y[3]'),
#  Text(0.2222222222222222, 0.3, 'Absolute magnitude(Mv) <= 15.515\ngini = 0.498\nsamples = 51\nvalue = [24, 27, 0, 0, 0, 0]\nclass = y[1]'),
#  Text(0.1111111111111111, 0.1, 'gini = 0.0\nsamples = 27\nvalue = [0, 27, 0, 0, 0, 0]\nclass = y[1]'),
#  Text(0.3333333333333333, 0.1, 'gini = 0.0\nsamples = 24\nvalue = [24, 0, 0, 0, 0, 0]\nclass = y[0]'),
#  Text(0.4444444444444444, 0.3, 'gini = 0.0\nsamples = 29\nvalue = [0, 0, 0, 29, 0, 0]\nclass = y[3]'),
#  Text(0.7777777777777778, 0.5, 'Absolute magnitude(Mv) <= -7.515\ngini = 0.497\nsamples = 52\nvalue = [0, 0, 0, 0, 28, 24]\nclass = y[4]'),
#  Text(0.6666666666666666, 0.3, 'gini = 0.0\nsamples = 24\nvalue = [0, 0, 0, 0, 0, 24]\nclass = y[5]'),
#  Text(0.8888888888888888, 0.3, 'gini = 0.0\nsamples = 28\nvalue = [0, 0, 0, 0, 28, 0]\nclass = y[4]')]

# %% [markdown]
# #### 2.2.1 Now let's bring the random forest into the game!
# - X, y and train test split may remain the same as before
# - create your random forest model for 5 estimators
# - fit the model to your training set
# - perform the predictions on your test set
# - evaluate your model (i.e. confusion matrix and classification_report)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators = 5)

# %%
rf.fit(xtrain, ytrain)
# Out:
# RandomForestClassifier(n_estimators=5)

# %%
rfpred = rf.predict(xtest)

# %%
print(confusion_matrix(ytest, rfpred), '\n')
print(classification_report(ytest, rfpred))
# Out:
# [[16  0  0  0  0  0]
#  [ 0 13  0  0  0  0]
#  [ 0  0 12  0  0  0]
#  [ 0  0  0 11  0  0]
#  [ 0  0  0  0 12  0]
#  [ 0  0  0  0  0 16]]
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        16
#            1       1.00      1.00      1.00        13
#            2       1.00      1.00      1.00        12
#            3       1.00      1.00      1.00        11
#            4       1.00      1.00      1.00        12
#            5       1.00      1.00      1.00        16
#
#     accuracy                           1.00        80
#    macro avg       1.00      1.00      1.00        80
# weighted avg       1.00      1.00      1.00        80

# %% [markdown]
# #### 2.2.2 Plot your random forest (only 5 trees)
# - plot the tree for each of the estimators in your random forest!

# %%
fig, ax = plt.subplots(nrows = len(rf.estimators_), ncols = 1, figsize = (10, 20))

for i in range(len(rf.estimators_)):
    tree.plot_tree(rf.estimators_[i],
                   feature_names = x.columns,
                   class_names = True,
                   filled = True,
                   ax=ax[i])

# %% [markdown]
# # Act 3 - Decision Tree and Random Forest on SF data
# #### 3.1.1 Decision Tree
# - read your star formation data --> The correct formatting
# - X should contain ['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870', 'F1100']
# - y is ['Evol Flag']
# - perform train test split
# - create your decsion tree model
# - fit the model to your training set
# - perform the predictions on your test set
# - evaluate your model (i.e. confusion matrix and classification_report)

# %%
cat = pd.read_csv('../Data/Star_Formation/HiGAL_clump_catalogue_correct_formatting.csv')

# %%
cols = ['F70', 'F160', 'F250', 'F350', 'F500', 'F21', 'F22', 'F24', 'F870', 'F1100']

# %%
x=cat[cols]
y=cat['EVOL_FLAG']
xtrain, xtest, ytrain, ytest = train_test_split(X, y, test_size=0.33, random_state=42)

dt=DecisionTreeClassifier()
dt.fit(xtrain, ytrain)

dtpred=dt.predict(xtest)

print(confusion_matrix(ytest, dtpred), '\n')
print(classification_report(ytest, dtpred))
# Out:
# [[ 13  11   1]
#  [ 14 264   7]
#  [  0  10 252]]
#
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.52      0.50        25
#          1.0       0.93      0.93      0.93       285
#          2.0       0.97      0.96      0.97       262
#
#     accuracy                           0.92       572
#    macro avg       0.79      0.80      0.80       572
# weighted avg       0.93      0.92      0.93       572

# %% [markdown]
# #### 3.1.2 Plot your decission tree

# %%
plt.figure(figsize = (15, 15))
tree.plot_tree(dt,
              feature_names = x.columns,
              filled = True)
# Out:
# [Text(0.29697951505016723, 0.9666666666666667, 'F70 <= 0.14\ngini = 0.551\nsamples = 1160\nvalue = [67, 584, 509]'),
#  Text(0.28360158862876256, 0.9, 'F500 <= 1.163\ngini = 0.279\nsamples = 694\nvalue = [67, 584, 43]'),
#  Text(0.14046822742474915, 0.8333333333333334, 'F500 <= 0.136\ngini = 0.62\nsamples = 95\nvalue = [47, 30, 18]'),
#  Text(0.12709030100334448, 0.7666666666666667, 'gini = 0.0\nsamples = 17\nvalue = [0, 0, 17]'),
#  Text(0.15384615384615385, 0.7666666666666667, 'F350 <= 2.89\ngini = 0.489\nsamples = 78\nvalue = [47, 30, 1]'),
#  Text(0.10702341137123746, 0.7, 'F160 <= 0.6\ngini = 0.443\nsamples = 66\nvalue = [45, 20, 1]'),
#  Text(0.05351170568561873, 0.6333333333333333, 'F250 <= 1.778\ngini = 0.287\nsamples = 30\nvalue = [25, 4, 1]'),
#  Text(0.026755852842809364, 0.5666666666666667, 'F350 <= 0.701\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.013377926421404682, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.04013377926421405, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.0802675585284281, 0.5666666666666667, 'F500 <= 0.632\ngini = 0.191\nsamples = 28\nvalue = [25, 3, 0]'),
#  Text(0.06688963210702341, 0.5, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0]'),
#  Text(0.09364548494983277, 0.5, 'F500 <= 0.743\ngini = 0.291\nsamples = 17\nvalue = [14, 3, 0]'),
#  Text(0.0802675585284281, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.10702341137123746, 0.43333333333333335, 'F500 <= 0.771\ngini = 0.124\nsamples = 15\nvalue = [14, 1, 0]'),
#  Text(0.09364548494983277, 0.36666666666666664, 'F500 <= 0.758\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0]'),
#  Text(0.0802675585284281, 0.3, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0]'),
#  Text(0.10702341137123746, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.12040133779264214, 0.36666666666666664, 'gini = 0.0\nsamples = 11\nvalue = [11, 0, 0]'),
#  Text(0.1605351170568562, 0.6333333333333333, 'F160 <= 1.262\ngini = 0.494\nsamples = 36\nvalue = [20, 16, 0]'),
#  Text(0.14715719063545152, 0.5666666666666667, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.17391304347826086, 0.5666666666666667, 'F24 <= 0.002\ngini = 0.469\nsamples = 32\nvalue = [20, 12, 0]'),
#  Text(0.1605351170568562, 0.5, 'F350 <= 1.449\ngini = 0.428\nsamples = 29\nvalue = [20, 9, 0]'),
#  Text(0.14715719063545152, 0.43333333333333335, 'gini = 0.0\nsamples = 9\nvalue = [9, 0, 0]'),
#  Text(0.17391304347826086, 0.43333333333333335, 'F500 <= 0.863\ngini = 0.495\nsamples = 20\nvalue = [11, 9, 0]'),
#  Text(0.14715719063545152, 0.36666666666666664, 'F160 <= 2.693\ngini = 0.408\nsamples = 7\nvalue = [2, 5, 0]'),
#  Text(0.13377926421404682, 0.3, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.1605351170568562, 0.3, 'F500 <= 0.731\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.14715719063545152, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.17391304347826086, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.20066889632107024, 0.36666666666666664, 'F250 <= 3.992\ngini = 0.426\nsamples = 13\nvalue = [9, 4, 0]'),
#  Text(0.18729096989966554, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.2140468227424749, 0.3, 'F160 <= 3.17\ngini = 0.5\nsamples = 8\nvalue = [4, 4, 0]'),
#  Text(0.20066889632107024, 0.23333333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.22742474916387959, 0.23333333333333334, 'F160 <= 6.72\ngini = 0.32\nsamples = 5\nvalue = [4, 1, 0]'),
#  Text(0.2140468227424749, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0]'),
#  Text(0.2408026755852843, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.18729096989966554, 0.5, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.20066889632107024, 0.7, 'F160 <= 5.057\ngini = 0.278\nsamples = 12\nvalue = [2, 10, 0]'),
#  Text(0.18729096989966554, 0.6333333333333333, 'gini = 0.0\nsamples = 10\nvalue = [0, 10, 0]'),
#  Text(0.2140468227424749, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.42673494983277593, 0.8333333333333334, 'F350 <= 2.569\ngini = 0.142\nsamples = 599\nvalue = [20, 554, 25]'),
#  Text(0.29431438127090304, 0.7666666666666667, 'F160 <= 4.934\ngini = 0.386\nsamples = 40\nvalue = [9, 30, 1]'),
#  Text(0.25418060200668896, 0.7, 'F250 <= 2.082\ngini = 0.219\nsamples = 33\nvalue = [3, 29, 1]'),
#  Text(0.2408026755852843, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.26755852842809363, 0.6333333333333333, 'F250 <= 9.765\ngini = 0.174\nsamples = 32\nvalue = [2, 29, 1]'),
#  Text(0.25418060200668896, 0.5666666666666667, 'F160 <= 4.174\ngini = 0.123\nsamples = 31\nvalue = [1, 29, 1]'),
#  Text(0.2408026755852843, 0.5, 'gini = 0.0\nsamples = 26\nvalue = [0, 26, 0]'),
#  Text(0.26755852842809363, 0.5, 'F250 <= 5.721\ngini = 0.56\nsamples = 5\nvalue = [1, 3, 1]'),
#  Text(0.25418060200668896, 0.43333333333333335, 'F250 <= 4.309\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.2408026755852843, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.26755852842809363, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.2809364548494983, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.2809364548494983, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.33444816053511706, 0.7, 'F350 <= 1.944\ngini = 0.245\nsamples = 7\nvalue = [6, 1, 0]'),
#  Text(0.3210702341137124, 0.6333333333333333, 'F160 <= 5.52\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0]'),
#  Text(0.3076923076923077, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.33444816053511706, 0.5666666666666667, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.34782608695652173, 0.6333333333333333, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0]'),
#  Text(0.5591555183946488, 0.7666666666666667, 'F500 <= 1.249\ngini = 0.119\nsamples = 559\nvalue = [11, 524, 24]'),
#  Text(0.4289297658862876, 0.7, 'F870 <= 0.069\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.41555183946488294, 0.6333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.4423076923076923, 0.6333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.68938127090301, 0.7, 'F160 <= 12.641\ngini = 0.113\nsamples = 556\nvalue = [9, 523, 24]'),
#  Text(0.4690635451505017, 0.6333333333333333, 'F160 <= 5.128\ngini = 0.076\nsamples = 481\nvalue = [4, 462, 15]'),
#  Text(0.3612040133779264, 0.5666666666666667, 'F350 <= 2.613\ngini = 0.04\nsamples = 345\nvalue = [0, 338, 7]'),
#  Text(0.32441471571906355, 0.5, 'F500 <= 3.995\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.3110367892976589, 0.43333333333333335, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.3377926421404682, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3979933110367893, 0.5, 'F250 <= 15.18\ngini = 0.035\nsamples = 341\nvalue = [0, 335, 6]'),
#  Text(0.36454849498327757, 0.43333333333333335, 'F870 <= 0.395\ngini = 0.021\nsamples = 287\nvalue = [0, 284, 3]'),
#  Text(0.3377926421404682, 0.36666666666666664, 'F500 <= 2.947\ngini = 0.014\nsamples = 274\nvalue = [0, 272, 2]'),
#  Text(0.32441471571906355, 0.3, 'F500 <= 2.946\ngini = 0.039\nsamples = 100\nvalue = [0, 98, 2]'),
#  Text(0.3110367892976589, 0.23333333333333334, 'F250 <= 12.282\ngini = 0.02\nsamples = 99\nvalue = [0, 98, 1]'),
#  Text(0.2976588628762542, 0.16666666666666666, 'gini = 0.0\nsamples = 95\nvalue = [0, 95, 0]'),
#  Text(0.32441471571906355, 0.16666666666666666, 'F160 <= 2.614\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.3110367892976589, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3377926421404682, 0.1, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.3377926421404682, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3511705685618729, 0.3, 'gini = 0.0\nsamples = 174\nvalue = [0, 174, 0]'),
#  Text(0.391304347826087, 0.36666666666666664, 'F870 <= 0.428\ngini = 0.142\nsamples = 13\nvalue = [0, 12, 1]'),
#  Text(0.3779264214046823, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.40468227424749165, 0.3, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0]'),
#  Text(0.431438127090301, 0.43333333333333335, 'F250 <= 15.274\ngini = 0.105\nsamples = 54\nvalue = [0, 51, 3]'),
#  Text(0.4180602006688963, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.44481605351170567, 0.36666666666666664, 'F250 <= 18.861\ngini = 0.073\nsamples = 53\nvalue = [0, 51, 2]'),
#  Text(0.431438127090301, 0.3, 'F250 <= 18.748\ngini = 0.188\nsamples = 19\nvalue = [0, 17, 2]'),
#  Text(0.4180602006688963, 0.23333333333333334, 'F350 <= 6.25\ngini = 0.105\nsamples = 18\nvalue = [0, 17, 1]'),
#  Text(0.40468227424749165, 0.16666666666666666, 'F350 <= 5.793\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.391304347826087, 0.1, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.4180602006688963, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.431438127090301, 0.16666666666666666, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0]'),
#  Text(0.44481605351170567, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.45819397993311034, 0.3, 'gini = 0.0\nsamples = 34\nvalue = [0, 34, 0]'),
#  Text(0.5769230769230769, 0.5666666666666667, 'F250 <= 4.914\ngini = 0.164\nsamples = 136\nvalue = [4, 124, 8]'),
#  Text(0.5501672240802675, 0.5, 'F350 <= 5.018\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.5367892976588629, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.5635451505016722, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6036789297658863, 0.5, 'F160 <= 5.151\ngini = 0.141\nsamples = 133\nvalue = [2, 123, 8]'),
#  Text(0.5903010033444817, 0.43333333333333335, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.617056856187291, 0.43333333333333335, 'F250 <= 24.564\ngini = 0.129\nsamples = 132\nvalue = [2, 123, 7]'),
#  Text(0.5217391304347826, 0.36666666666666664, 'F350 <= 3.297\ngini = 0.086\nsamples = 113\nvalue = [2, 108, 3]'),
#  Text(0.48494983277591974, 0.3, 'F350 <= 3.147\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.47157190635451507, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.4983277591973244, 0.23333333333333334, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5585284280936454, 0.3, 'F250 <= 7.372\ngini = 0.071\nsamples = 110\nvalue = [1, 106, 3]'),
#  Text(0.5250836120401338, 0.23333333333333334, 'F250 <= 7.225\ngini = 0.37\nsamples = 9\nvalue = [1, 7, 1]'),
#  Text(0.5117056856187291, 0.16666666666666666, 'F250 <= 7.014\ngini = 0.219\nsamples = 8\nvalue = [0, 7, 1]'),
#  Text(0.4983277591973244, 0.1, 'gini = 0.0\nsamples = 6\nvalue = [0, 6, 0]'),
#  Text(0.5250836120401338, 0.1, 'F250 <= 7.161\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.5117056856187291, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.5384615384615384, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.5384615384615384, 0.16666666666666666, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.5919732441471572, 0.23333333333333334, 'F350 <= 4.111\ngini = 0.039\nsamples = 101\nvalue = [0, 99, 2]'),
#  Text(0.5652173913043478, 0.16666666666666666, 'F250 <= 13.247\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.5518394648829431, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.5785953177257525, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6187290969899666, 0.16666666666666666, 'F500 <= 2.759\ngini = 0.021\nsamples = 96\nvalue = [0, 95, 1]'),
#  Text(0.6053511705685619, 0.1, 'F500 <= 2.674\ngini = 0.142\nsamples = 13\nvalue = [0, 12, 1]'),
#  Text(0.5919732441471572, 0.03333333333333333, 'gini = 0.0\nsamples = 12\nvalue = [0, 12, 0]'),
#  Text(0.6187290969899666, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6321070234113713, 0.1, 'gini = 0.0\nsamples = 83\nvalue = [0, 83, 0]'),
#  Text(0.7123745819397993, 0.36666666666666664, 'F160 <= 7.748\ngini = 0.332\nsamples = 19\nvalue = [0, 15, 4]'),
#  Text(0.6989966555183946, 0.3, 'F500 <= 11.408\ngini = 0.5\nsamples = 8\nvalue = [0, 4, 4]'),
#  Text(0.68561872909699, 0.23333333333333334, 'F350 <= 19.256\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.6722408026755853, 0.16666666666666666, 'F500 <= 4.639\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.6588628762541806, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.68561872909699, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.6989966555183946, 0.16666666666666666, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.7123745819397993, 0.23333333333333334, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.725752508361204, 0.3, 'gini = 0.0\nsamples = 11\nvalue = [0, 11, 0]'),
#  Text(0.9096989966555183, 0.6333333333333333, 'F350 <= 22.602\ngini = 0.32\nsamples = 75\nvalue = [5, 61, 9]'),
#  Text(0.8461538461538461, 0.5666666666666667, 'F350 <= 19.424\ngini = 0.472\nsamples = 39\nvalue = [5, 27, 7]'),
#  Text(0.8127090301003345, 0.5, 'F160 <= 27.484\ngini = 0.404\nsamples = 32\nvalue = [5, 24, 3]'),
#  Text(0.7859531772575251, 0.43333333333333335, 'F250 <= 56.316\ngini = 0.35\nsamples = 29\nvalue = [3, 23, 3]'),
#  Text(0.7725752508361204, 0.36666666666666664, 'F160 <= 12.773\ngini = 0.309\nsamples = 28\nvalue = [2, 23, 3]'),
#  Text(0.7591973244147158, 0.3, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.7859531772575251, 0.3, 'F500 <= 2.918\ngini = 0.263\nsamples = 27\nvalue = [2, 23, 2]'),
#  Text(0.7391304347826086, 0.23333333333333334, 'F500 <= 2.61\ngini = 0.5\nsamples = 6\nvalue = [1, 4, 1]'),
#  Text(0.725752508361204, 0.16666666666666666, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0]'),
#  Text(0.7525083612040134, 0.16666666666666666, 'F160 <= 16.104\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1]'),
#  Text(0.7391304347826086, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.7658862876254181, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8327759197324415, 0.23333333333333334, 'F160 <= 13.106\ngini = 0.177\nsamples = 21\nvalue = [1, 19, 1]'),
#  Text(0.8060200668896321, 0.16666666666666666, 'F160 <= 13.07\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.7926421404682275, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8193979933110368, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.8595317725752508, 0.16666666666666666, 'F350 <= 6.174\ngini = 0.105\nsamples = 18\nvalue = [1, 17, 0]'),
#  Text(0.8461538461538461, 0.1, 'F350 <= 6.14\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0]'),
#  Text(0.8327759197324415, 0.03333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8595317725752508, 0.03333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8729096989966555, 0.1, 'gini = 0.0\nsamples = 15\nvalue = [0, 15, 0]'),
#  Text(0.7993311036789298, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0]'),
#  Text(0.8394648829431438, 0.43333333333333335, 'F870 <= 0.57\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0]'),
#  Text(0.8260869565217391, 0.36666666666666664, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0]'),
#  Text(0.8528428093645485, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.8795986622073578, 0.5, 'F250 <= 22.133\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4]'),
#  Text(0.8662207357859532, 0.43333333333333335, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8929765886287625, 0.43333333333333335, 'F250 <= 58.396\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 4]'),
#  Text(0.8795986622073578, 0.36666666666666664, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4]'),
#  Text(0.9063545150501672, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.9732441471571907, 0.5666666666666667, 'F160 <= 281.215\ngini = 0.105\nsamples = 36\nvalue = [0, 34, 2]'),
#  Text(0.959866220735786, 0.5, 'F870 <= 0.152\ngini = 0.056\nsamples = 35\nvalue = [0, 34, 1]'),
#  Text(0.9464882943143813, 0.43333333333333335, 'F250 <= 102.539\ngini = 0.278\nsamples = 6\nvalue = [0, 5, 1]'),
#  Text(0.9331103678929766, 0.36666666666666664, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0]'),
#  Text(0.959866220735786, 0.36666666666666664, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.9732441471571907, 0.43333333333333335, 'gini = 0.0\nsamples = 29\nvalue = [0, 29, 0]'),
#  Text(0.9866220735785953, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.3103574414715719, 0.9, 'gini = 0.0\nsamples = 466\nvalue = [0, 0, 466]')]

# %% [markdown]
# #### 3.2.1 Is the result from the random forest any better?
# - X, y and train test split may remain the same as before
# - create your random forest model for 5 estimators
# - fit the model to your training set
# - perform the predictions on your test set
# - evaluate your model (i.e. confusion matrix and classification_report)

# %%
rf = RandomForestClassifier(n_estimators = 5)

rf.fit(xtrain, ytrain)
rfpred = rf.predict(xtest)

print(confusion_matrix(ytest, rfpred), '\n')
print(classification_report(ytest, rfpred))
# Out:
# [[ 11  14   0]
#  [ 12 272   1]
#  [  0  13 249]]
#
#               precision    recall  f1-score   support
#
#          0.0       0.48      0.44      0.46        25
#          1.0       0.91      0.95      0.93       285
#          2.0       1.00      0.95      0.97       262
#
#     accuracy                           0.93       572
#    macro avg       0.79      0.78      0.79       572
# weighted avg       0.93      0.93      0.93       572

# %% [markdown]
# #### 3.2.2 Plot your random forest (only 5 trees)
# - plot the tree for each of the estimators in your random forest!

# %%
fig, ax = plt.subplots(nrows = len(rf.estimators_), ncols = 1, figsize = (10, 25))

for i in range(len(rf.estimators_)):
    tree.plot_tree(rf.estimators_[i],
                   feature_names = x.columns,
                   class_names = True,
                   filled = True,
                   ax=ax[i])

# %% [markdown]
# #### 3.3 Re-run your code in 3.2.1, however, set n_estimator = 200. Does it improve your result?

# %%
rf = RandomForestClassifier(n_estimators = 200)

rf.fit(xtrain, ytrain)
rfpred = rf.predict(xtest)

print(confusion_matrix(ytest, rfpred), '\n')
print(classification_report(ytest, rfpred))
# Out:
# [[ 10  15   0]
#  [  9 276   0]
#  [  0  14 248]]
#
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.40      0.45        25
#          1.0       0.90      0.97      0.94       285
#          2.0       1.00      0.95      0.97       262
#
#     accuracy                           0.93       572
#    macro avg       0.81      0.77      0.79       572
# weighted avg       0.93      0.93      0.93       572

# %% [markdown]
# ![image.png](attachment:image.png)
